# %% [markdown]
# # Sprint 008 D2 — frozen-rule retrospective validation
#
# Evaluates the unchanged M1 and M2 exclude-U rules on 2024-01-01 through 2026-07-10.
#
# - Design: `docs/tmp/sprint008_d2_design.md` (accepted, reviewed commit `c2ba972`)
# - Runner: `scripts/run_sprint008_d2_fixed_exclusion_validation.py`
# - Historical D1 gate `STOP_NO_THRESHOLDS` is preserved
# - Retrospective validation, not a pristine holdout
# - Do not start D3 from this notebook

# %%
import sys
from pathlib import Path


def _repo_root() -> Path:
    here = Path.cwd().resolve()
    for candidate in (here, *here.parents):
        if (candidate / "src" / "backtest").is_dir() and (candidate / "setup.py").exists():
            return candidate
    raise RuntimeError("Could not locate MomentumCVG repo root")


REPO_ROOT = _repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from src.backtest.sprint008_d2_fixed_exclusion_validation import run_fixed_exclusion_validation

result = run_fixed_exclusion_validation()
print("calendar", result.calendar_validation)
for measurement, contrast in result.inference["contrasts"].items():
    print(measurement, contrast["label"], contrast["mean"], contrast["p_adjusted"])
